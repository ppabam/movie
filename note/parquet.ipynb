# %%
import pandas as pd

# %%
from movie.api.call import gen_url, call_api

# %%
ymd = "20120102"

# %%
data = call_api(dt=ymd)

# %%
df = pd.DataFrame(data)
df.head(3)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd         movieNm      openDt  \
# 0    1    1         0           OLD  20112207  미션임파서블:고스트프로토콜  2011-12-15
# 1    2    2         1           OLD  20112621   셜록홈즈 : 그림자 게임  2011-12-21
# 2    3    3        -1           OLD  20110295           마이 웨이  2011-12-21
#
#      salesAmt salesShare   salesInten salesChange     salesAcc audiCnt  \
# 0  1033680000       34.0  -1742380500       -62.8  41574788500  138853
# 1   494700500       16.3   -681322000       -57.9  11173028000   68111
# 2   419655000       13.8   -769403500       -64.7  13422552500   58357
#
#   audiInten audiChange  audiAcc scrnCnt showCnt
# 0   -214421      -60.7  5467288     662    3009
# 1    -84893      -55.5  1510972     350    1728
# 2    -95144        -62  1797900     574    2242

# %%
df['dt'] = ymd
df.head(3)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd         movieNm      openDt  \
# 0    1    1         0           OLD  20112207  미션임파서블:고스트프로토콜  2011-12-15
# 1    2    2         1           OLD  20112621   셜록홈즈 : 그림자 게임  2011-12-21
# 2    3    3        -1           OLD  20110295           마이 웨이  2011-12-21
#
#      salesAmt salesShare   salesInten salesChange     salesAcc audiCnt  \
# 0  1033680000       34.0  -1742380500       -62.8  41574788500  138853
# 1   494700500       16.3   -681322000       -57.9  11173028000   68111
# 2   419655000       13.8   -769403500       -64.7  13422552500   58357
#
#   audiInten audiChange  audiAcc scrnCnt showCnt        dt
# 0   -214421      -60.7  5467288     662    3009  20120102
# 1    -84893      -55.5  1510972     350    1728  20120102
# 2    -95144        -62  1797900     574    2242  20120102

# %%
df.to_parquet('~/tmp/test_parquet', partition_cols=['dt'])

# %%
df = pd.read_parquet("~/tmp/test_parquet")
df.head(3)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd         movieNm      openDt  \
# 0    1    1         0           OLD  20112207  미션임파서블:고스트프로토콜  2011-12-15
# 1    2    2         1           OLD  20110295           마이 웨이  2011-12-21
# 2    3    3        -1           OLD  20112621   셜록홈즈 : 그림자 게임  2011-12-21
#
#      salesAmt salesShare  salesInten salesChange     salesAcc audiCnt  \
# 0  2776060500       36.3  -415699000         -13  40541108500  353274
# 1  1189058500       15.6  -105894500        -8.2  13002897500  153501
# 2  1176022500       15.4  -210328500       -15.2  10678327500  153004
#
#   audiInten audiChange  audiAcc scrnCnt showCnt        dt
# 0    -60106      -14.5  5328435     697    3223  20120101
# 1    -16465       -9.7  1739543     588    2321  20120101
# 2    -31283        -17  1442861     360    1832  20120101

# %%
df['dt'].unique()
# Out:
# [20120101, 20120102]
# Categories (2, int32): [20120101, 20120102]
